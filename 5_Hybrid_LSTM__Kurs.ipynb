# %% [markdown]
# <a href="https://colab.research.google.com/github/gladysadyaz/RAYA73/blob/main/5_Hybrid_LSTM__Kurs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import random
import warnings
import itertools
import statsmodels.api as sm
import tensorflow.keras as keras
import seaborn as sns
import tensorflow as tf
import gc

from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from sklearn.metrics import *
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping
from numpy import array

# %matplotlib inline
plt.style.use('fivethirtyeight')
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # MODELING

# %% [markdown]
# # B. LONG SHORT TERM MEMORY

# %% [markdown]
# ## Splitting & Scaling

# %%
file_path_actual = "/content/drive/My Drive/Colab Notebooks/wisman bali-kurs (1).xlsx"
df_actual = pd.read_excel(file_path_actual, sheet_name='Sheet1')
df_actual['Date'] = pd.to_datetime(df_actual['Date'], format='%d/%m/%Y')
df_actual.set_index('Date', inplace=True)
print(df_actual.head())
# Out:
#              Kurs  Wisman Bali  Hari Raya
# Date
# 2023-01-01  15592        10626          1
# 2023-01-02  15572        12338          1
# 2023-01-03  15590        12122          1
# 2023-01-04  15615        11957          1
# 2023-01-05  15610        13463          1

# %%
file_path = "/content/drive/My Drive/Colab Notebooks/varx_residuals.xlsx"
df = pd.read_excel(file_path, sheet_name='FIXVARXRAYA')
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#              Kurs  Wisman Bali
# Date
# 2023-01-02 -15.18         1733
# 2023-01-03  11.45         2130
# 2023-01-04  36.80         2138
# 2023-01-05  37.25         3945
# 2023-01-06  66.38         3851

# %%
steps_slicing = 90
df_final = df_actual[:-steps_slicing]
df_update = df_actual[-steps_slicing:]

# %%
# Select only the 'Kurs Dollar' column for input and output
df_residual = df['Kurs']
data2 = df_residual.copy()
data2
# Out:
# Date
# 2023-01-02   -15.18
# 2023-01-03    11.45
# 2023-01-04    36.80
# 2023-01-05    37.25
# 2023-01-06    66.38
#               ...
# 2025-01-16   755.80
# 2025-01-17   748.95
# 2025-01-18   752.28
# 2025-01-19   750.38
# 2025-01-20   748.00
# Name: Kurs, Length: 750, dtype: float64

# %%
# Normalize the data for LSTM
scaler2 = MinMaxScaler()
scaled_data2 = scaler2.fit_transform(data2.values.reshape(-1, 1))

# %%
# Prepare the dataset for LSTM
def create_dataset(data, time_step=1):
    dataX, dataY = [], []
    for i in range(len(data)-time_step-1):
        a = data[i:(i+time_step), 0]  # Use only the first column
        dataX.append(a)
        dataY.append(data[i + time_step, 0])  # Use only the first column
    return np.array(dataX), np.array(dataY)

# %%
# Set the time step
time_step = 5

# Create the dataset for LSTM
X2, y2 = create_dataset(scaled_data2, time_step)

# Reshape X2 to be [samples, time steps, features] which is required for LSTM
X2 = X2.reshape(X2.shape[0], X2.shape[1], 1)

# %%
test_size2 = 90
train_size2 = len(X2) - test_size2
X2_train, X2_test = X2[:train_size2], X2[train_size2:]
y2_train, y2_test = y2[:train_size2], y2[train_size2:]

# %% [markdown]
# ## Hypertuning Parameters

# %%
# Function to create model for LSTM
def create_model_lstm2(units1, units2, dropout_rate, learning_rate, init_scheme):
    seed_value = 54
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)
    model = Sequential()
    model.add(LSTM(units=units1, return_sequences=True, input_shape=(time_step, 1), kernel_initializer=init_scheme))
    model.add(Dropout(rate=dropout_rate))
    model.add(LSTM(units=units2, kernel_initializer=init_scheme))
    model.add(Dropout(rate=dropout_rate))
    model.add(Dense(1, activation='linear', kernel_initializer=init_scheme))
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    return model

# %%
# Define the hyperparameter grid for LSTM
param_grid_lstm2 = {
    'units1': [50, 100],
    'units2': [50, 100],
    'dropout_rate': [0, 0.2],
    'learning_rate': [0.01, 0.001],
    'batch_size': [16, 32, 64],
    'epochs': [100],
    'init_scheme': ['glorot_uniform','he_uniform']
}

# %%
from itertools import product
# Convert param_grid to a list of dictionaries
param_list_lstm2 = list(product(param_grid_lstm2['units1'],
                                param_grid_lstm2['units2'],
                                param_grid_lstm2['dropout_rate'],
                                param_grid_lstm2['learning_rate'],
                                param_grid_lstm2['batch_size'],
                                param_grid_lstm2['epochs'],
                                param_grid_lstm2['init_scheme'],))

# %%
from tqdm.notebook import tqdm

# Inisialisasi tracking
best_score_lstm2 = float('inf')
best_params_lstm2 = None
best_model_lstm2 = None

# Total kombinasi
total_combinations = len(param_list_lstm2)

print("Starting LSTM2 tuning...\n")

# Loop dengan tqdm
for i, params in enumerate(tqdm(param_list_lstm2, desc="LSTM2 Grid Search", unit="comb")):
    units1, units2, dropout_rate, learning_rate, batch_size, epochs, init_scheme = params

    # Cetak 1x info konfigurasi saat ini
    print(f"Training model {i+1}/{total_combinations} | "
          f"units1={units1}, units2={units2}, dropout={dropout_rate}, "
          f"lr={learning_rate}, batch={batch_size}, epochs={epochs}, init={init_scheme}")

    model_lstm2 = create_model_lstm2(units1, units2, dropout_rate, learning_rate, init_scheme)

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    history_lstm2 = model_lstm2.fit(
        X2_train, y2_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(X2_test, y2_test),
        callbacks=[early_stopping],
        verbose=0
    )

    val_loss = min(history_lstm2.history['val_loss'])

    if val_loss < best_score_lstm2:
        best_score_lstm2 = val_loss
        best_params_lstm2 = {
            'units1': units1,
            'units2': units2,
            'dropout_rate': dropout_rate,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'epochs': epochs,
            'init_scheme': init_scheme
        }
        best_model_lstm2 = model_lstm2

# Hasil akhir
print(f"\n Best LSTM score: {best_score_lstm2:.6f} with parameters:\n{best_params_lstm2}")
# Out:
# Starting LSTM2 tuning...
# LSTM2 Grid Search:   0%|          | 0/96 [00:00<?, ?comb/s]
# Training model 1/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 2/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 3/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 4/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 5/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 6/96 | units1=50, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 7/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 8/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 9/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 10/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 11/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 12/96 | units1=50, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 13/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 14/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 15/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 16/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 17/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 18/96 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 19/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 20/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 21/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 22/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 23/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 24/96 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 25/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 26/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 27/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 28/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 29/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 30/96 | units1=50, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 31/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 32/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 33/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 34/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 35/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 36/96 | units1=50, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 37/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 38/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 39/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 40/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 41/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 42/96 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 43/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 44/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 45/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 46/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 47/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 48/96 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 49/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 50/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 51/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 52/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 53/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 54/96 | units1=100, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 55/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 56/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 57/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 58/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 59/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 60/96 | units1=100, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 61/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 62/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 63/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 64/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 65/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 66/96 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 67/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 68/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 69/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 70/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 71/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 72/96 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 73/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 74/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 75/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 76/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 77/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 78/96 | units1=100, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 79/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 80/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 81/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 82/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 83/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 84/96 | units1=100, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 85/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 86/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 87/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 88/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 89/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 90/96 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 91/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 92/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 93/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 94/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 95/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 96/96 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
#
#  Best LSTM score: 0.000762 with parameters:
# {'units1': 50, 'units2': 50, 'dropout_rate': 0, 'learning_rate': 0.001, 'batch_size': 16, 'epochs': 100, 'init_scheme': 'he_uniform'}

# %% [markdown]
# ## Model

# %%
best_params_lstm2
# Out:
# {'units1': 50,
#  'units2': 50,
#  'dropout_rate': 0,
#  'learning_rate': 0.001,
#  'batch_size': 16,
#  'epochs': 100,
#  'init_scheme': 'he_uniform'}

# %%
# Ambil parameter terbaik dari hasil grid search
manual_units1_lstm2 = best_params_lstm2['units1']
manual_units2_lstm2 = best_params_lstm2['units2']
manual_dropout_rate_lstm2 = best_params_lstm2['dropout_rate']
manual_learning_rate_lstm2 = best_params_lstm2['learning_rate']
manual_batch_size_lstm2 = best_params_lstm2['batch_size']
manual_epochs_lstm2 = best_params_lstm2['epochs']
manual_init_scheme_lstm2 = best_params_lstm2['init_scheme']

# Buat model dengan parameter terbaik
model_manual_lstm2 = create_model_lstm2(manual_units1_lstm2,
                                        manual_units2_lstm2,
                                        manual_dropout_rate_lstm2,
                                        manual_learning_rate_lstm2,
                                        manual_init_scheme_lstm2)

# Early stopping callbacks
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=50,
                               restore_best_weights=True)

# Latih model dengan parameter terbaik
history_manual_lstm2 = model_manual_lstm2.fit(X2_train,
                                              y2_train,
                                              batch_size=manual_batch_size_lstm2,
                                              epochs=manual_epochs_lstm2,
                                              validation_data=(X2_test, y2_test),
                                              callbacks=[early_stopping],
                                              verbose=1)
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0108 - val_loss: 0.0028
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 9.9761e-04
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 9.7581e-04
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 9.5565e-04
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 9.3704e-04
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 9.1990e-04
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 9.0415e-04
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - val_loss: 8.8972e-04
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 8.7652e-04
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 8.6448e-04
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 8.5353e-04
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 8.4358e-04
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 8.3457e-04
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 8.2643e-04
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 8.1908e-04
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 8.1247e-04
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 8.0654e-04
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 8.0123e-04
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.9647e-04
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.9223e-04
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.8845e-04
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.8509e-04
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.8211e-04
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 7.7946e-04
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 7.7712e-04
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.7505e-04
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 7.7322e-04
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.7161e-04
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.7020e-04
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6896e-04
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6787e-04
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6692e-04
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6609e-04
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6538e-04
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6476e-04
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6423e-04
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 7.6378e-04
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6339e-04
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6307e-04
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6280e-04
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 7.6258e-04
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 7.6240e-04
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6226e-04
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6214e-04
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6206e-04
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6200e-04
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6195e-04
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6192e-04
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6191e-04
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6190e-04
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0011 - val_loss: 7.6190e-04
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.6191e-04
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.6192e-04
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.6193e-04
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.6194e-04
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6195e-04
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6196e-04
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6197e-04
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6198e-04
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6199e-04
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6200e-04
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6201e-04
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6202e-04
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6204e-04
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6206e-04
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6209e-04
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6212e-04
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6216e-04
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6222e-04
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6229e-04
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6237e-04
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 7.6246e-04
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 7.6258e-04
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6271e-04
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6286e-04
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6303e-04
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.6322e-04

# %%
# Summary model
model_manual_lstm2.summary()
# Out:
# Model: "sequential_96"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_192 (LSTM)                 │ (None, 5, 50)          │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_192 (Dropout)           │ (None, 5, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_193 (LSTM)                 │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_193 (Dropout)           │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 91,955 (359.20 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 61,304 (239.47 KB)

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(history_manual_lstm2.history['loss'], label='Training Loss', linewidth=1)
plt.plot(history_manual_lstm2.history['val_loss'], label='Validation Loss', linewidth=1)
plt.title('LSTM Model Loss\n', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LSTM Model Loss\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Predict on the training data for LSTM
train_predict_lstm2 = model_manual_lstm2.predict(X2_train)
test_predict_lstm2 = model_manual_lstm2.predict(X2_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Inverse transform the predictions for LSTM
train_predict_lstm2 = scaler2.inverse_transform(train_predict_lstm2)
test_predict_lstm2 = scaler2.inverse_transform(test_predict_lstm2)
y2_train = scaler2.inverse_transform(y2_train.reshape(-1, 1))
y2_test = scaler2.inverse_transform(y2_test.reshape(-1, 1))

# %% [markdown]
# ## Evaluation & Visualization

# %%
# Calculate MAPE for LSTM
train_mape_kurs_lstm2 = mean_absolute_percentage_error(y2_train, train_predict_lstm2)
test_mape_kurs_lstm2 = mean_absolute_percentage_error(y2_test, test_predict_lstm2)

print(f'Training MAPE (Kurs Dollar) LSTM: {train_mape_kurs_lstm2:.4f}')
print(f'Testing MAPE (Kurs Dollar) LSTM: {test_mape_kurs_lstm2:.4f}')
# Out:
# Training MAPE (Kurs Dollar) LSTM: 0.8024
# Testing MAPE (Kurs Dollar) LSTM: 4.5508

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(y2_train, label='Actual Residual (Training)', linewidth=1)
plt.plot(train_predict_lstm2, label='Predicted Residual (Training)', linewidth=1)
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('LSTM: Actual vs Predicted Kurs Dollar (Training Data Residual)\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(y2_test, label='Actual Residual(Testing)', linewidth=1)
plt.plot(test_predict_lstm2, label='Predicted Residual(Testing)', linewidth=1)
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('LSTM: Actual vs Predicted Kurs Dollar (Testing Data Residual)\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Forecasting

# %%
# Forecasting for the next 90 steps
predictions_lstm2 = []
input_data_lstm2 = scaled_data2[-time_step:].reshape(1, time_step, 1)

for _ in range(90):
    pred = model_manual_lstm2.predict(input_data_lstm2)
    predictions_lstm2.append(pred[0])
    input_data_lstm2 = np.append(input_data_lstm2[:, 1:, :], [[pred[0]]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
# Inverse transform the predictions to original scale
predictions_lstm2 = scaler2.inverse_transform(predictions_lstm2)

# Save predictions to DataFrame
df_future_predictions_lstm2 = pd.DataFrame(predictions_lstm2, columns=['Predicted Residual Kurs Dollar'])

# Assuming df_update is the dataframe where you want to align future predictions, here aligning index with the valid_data's last 7 steps.
df_future_predictions_lstm2.index = df_update.index

# Display the future predictions DataFrame
df_future_predictions_lstm2
# Out:
#             Predicted Residual Kurs Dollar
# Date
# 2024-10-23                          732.89
# 2024-10-24                          720.88
# 2024-10-25                          711.33
# 2024-10-26                          703.37
# 2024-10-27                          696.46
# ...                                    ...
# 2025-01-16                          642.02
# 2025-01-17                          642.02
# 2025-01-18                          642.02
# 2025-01-19                          642.02
# 2025-01-20                          642.02
#
# [90 rows x 1 columns]

# %%
# Plot Data
plt.figure(figsize=(20, 8))
plt.plot(df.iloc[-90:]['Kurs'], linewidth=1, label='History')
plt.plot(df_future_predictions_lstm2['Predicted Residual Kurs Dollar'], linewidth=1, label='Predict')
plt.xlabel('Date')
plt.ylabel('Value (Rp)')
plt.title('Plot Data Residual Kurs Dollar - Forecasting LSTM\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# # C. HYBRID VARX-LSTM

# %% [markdown]
# ## Model

# %%
file_path_forecast = "/content/drive/My Drive/Colab Notebooks/varx_forecast.xlsx"
df_forecast = pd.read_excel(file_path_forecast, sheet_name='FIXVARXRAYA')
df_forecast['Date'] = pd.to_datetime(df_forecast['Date'], format='%d/%m/%Y')
df_forecast.set_index('Date', inplace=True)
print(df_forecast.head())
# Out:
#                Kurs  Wisman Bali
# Date
# 2024-10-23 15565.71        19106
# 2024-10-24 15562.07        19355
# 2024-10-25 15566.28        20336
# 2024-10-26 15567.76        20100
# 2024-10-27 15565.30        20132

# %%
df_linear = df_forecast[['Kurs']]
df_linear
# Out:
#                Kurs
# Date
# 2024-10-23 15565.71
# 2024-10-24 15562.07
# 2024-10-25 15566.28
# 2024-10-26 15567.76
# 2024-10-27 15565.30
# ...             ...
# 2025-01-16 15622.20
# 2025-01-17 15624.05
# 2025-01-18 15620.72
# 2025-01-19 15622.62
# 2025-01-20 15624.00
#
# [90 rows x 1 columns]

# %%
df_nonlinear = df_future_predictions_lstm2.copy()
df_nonlinear
# Out:
#             Predicted Residual Kurs Dollar
# Date
# 2024-10-23                          732.89
# 2024-10-24                          720.88
# 2024-10-25                          711.33
# 2024-10-26                          703.37
# 2024-10-27                          696.46
# ...                                    ...
# 2025-01-16                          642.02
# 2025-01-17                          642.02
# 2025-01-18                          642.02
# 2025-01-19                          642.02
# 2025-01-20                          642.02
#
# [90 rows x 1 columns]

# %%
df_hybrid = pd.DataFrame({
    'Hybrid Kurs Dollar': df_linear['Kurs'] + df_nonlinear['Predicted Residual Kurs Dollar'],
})
df_hybrid
# Out:
#             Hybrid Kurs Dollar
# Date
# 2024-10-23            16298.60
# 2024-10-24            16282.95
# 2024-10-25            16277.61
# 2024-10-26            16271.13
# 2024-10-27            16261.76
# ...                        ...
# 2025-01-16            16264.22
# 2025-01-17            16266.07
# 2025-01-18            16262.74
# 2025-01-19            16264.64
# 2025-01-20            16266.02
#
# [90 rows x 1 columns]

# %%
df_hybrid_final = pd.merge(df_update['Kurs'], df_hybrid, left_index=True, right_index=True)
print(df_hybrid_final.shape)
df_hybrid_final
# Out:
# (90, 2)
#              Kurs  Hybrid Kurs Dollar
# Date
# 2024-10-23  15620            16298.60
# 2024-10-24  15593            16282.95
# 2024-10-25  15629            16277.61
# 2024-10-26  15629            16271.13
# 2024-10-27  15629            16261.76
# ...           ...                 ...
# 2025-01-16  16378            16264.22
# 2025-01-17  16373            16266.07
# 2025-01-18  16373            16262.74
# 2025-01-19  16373            16264.64
# 2025-01-20  16372            16266.02
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Evaluation & Visualization

# %%
# Define true and predicted 'Close' values
y_true = df_hybrid_final['Kurs']
y_pred = df_hybrid_final['Hybrid Kurs Dollar']

# %%
mape = mean_absolute_percentage_error(y_true, y_pred) * 100  # dikali 100 agar jadi persentase
print(f"Mean Absolute Percentage Error (MAPE) for Hybrid Kurs Dollar: {mape:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE) for Hybrid Kurs Dollar: 1.77%

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(df_final.iloc[-10:]['Kurs'], linewidth=1, label='History')
plt.plot(df_hybrid_final['Kurs'], linewidth=1, label='Actual')
plt.plot(df_hybrid_final['Hybrid Kurs Dollar'], linewidth=1, label='Predict')
plt.xlabel('Date')
plt.ylabel('Value (Rp)')
plt.title('Plot Data Kurs Dollar - Forecasting Hybrid\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
